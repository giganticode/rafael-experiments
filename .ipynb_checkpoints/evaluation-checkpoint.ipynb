# %%
# %matplotlib inline

from math import log

def to_bin_entropy(ev):
    ev.data.Entropy = ev.data.Entropy / log(2)
    return ev

# %% [markdown]
# # Evaluation after epoch=159

# %%
from langmodels.evaluation import EvaluationResult

evaluation159 = EvaluationResult.from_path('evaluation-test-159')
evaluation159 = to_bin_entropy(evaluation159)
# Out:
# 2020-07-06 12:46:55,320 [numexpr.utils] INFO: NumExpr defaulting to 4 threads.

# %% [markdown]
# ## Different Projects

# %%
per_project_entropies = evaluation159.aggregate(['Project']).data
per_project_entropies.sort_values(['Entropy'])
# Out:
#                                 n_samples  \
# Project
# postmark-java                        3917
# ibatis-handling-joins                1984
# logmx                                 373
# mod-installer                        5460
# servletjspdemo                        699
# MCBans                              37271
# RPS                                  4113
# fasthat                             51121
# Clara                                9765
# twitterdroid                         5438
# 1160-Scouting-App                   11921
# osgiutils_1                          1079
# GrandUI                             51778
# gat                                  2097
# xebia-petclinic                     11488
# confcaller                           2488
# bioclipse.opentox                   30759
# asakusafw                         1867190
# jbpm-plugin                         11945
# rdt                               1690615
# Journal.IO                          17470
# hands-on-spring-batch                3002
# PipesJ2ME                            6311
# vraptor-dash                        16275
# SnippingTool                        17210
# spring-social-google                16925
# oddjob                             569644
# sveditor                           591314
# camel-aries-blueprint-tutorial       3931
# jADT                                67749
# android-tether                      59170
# d2rq                               179024
# koku-service-api                    19113
# naturvielfalt_android                4858
# disruptor_1                         21572
# AndProject                          14364
# edsdk4j                             17575
# thucydides-showcase                  3294
#
#                                                                           example  \
# Project
# postmark-java                                                       <comment></t>
# ibatis-handling-joins                                     sql|Session|Factory</t>
# logmx                                                                       (</t>
# mod-installer                                                   getLog|o|File</t>
# servletjspdemo                                                              (</t>
# MCBans                                                       "%|B|AD|WOR|D|%"</t>
# RPS                                                                       "|"</t>
# fasthat                                              "</|b|>|<|/|p|>|<|h|r|>"</t>
# Clara                           inf|l|ate|_d|uplic|ate|Id|_|exception|Throw|n</t>
# twitterdroid                                                                {</t>
# 1160-Scouting-App                            6|08|8|16|09|6|5|15|5|26|09|64|l</t>
# osgiutils_1                                                              void</t>
# GrandUI                                                             <comment></t>
# gat                                                                         )</t>
# xebia-petclinic                                                     <comment></t>
# confcaller                                                              super</t>
# bioclipse.opentox                                                      return</t>
# asakusafw                                                           em|it|ter</t>
# jbpm-plugin                                  6|2|29|67|98|56|12|8|47|9|5|3|1l</t>
# rdt                                                                        ""</t>
# Journal.IO                      test|NoSuch|Element|Exception|With|Un|do|Itera...
# hands-on-spring-batch                               read|_|skip|_|employ|e|es</t>
# PipesJ2ME                                                           <comment></t>
# vraptor-dash                                 getSec|ond|Level|Cache|Hit|Count</t>
# SnippingTool                         ch|ck|b|x|Enable|Multi|sn|ipp|et|Support</t>
# spring-social-google                                           "|page|Token|"</t>
# oddjob                          test|Day|L|ight|S|av|ing|In|Aut|um|n|Over|M|id...
# sveditor                                                                   ""</t>
# camel-aries-blueprint-tutorial                                        "|od|d"</t>
# jADT                                                      test|Exist|ing|File</t>
# android-tether                                             m|Is|Sh|r|in|k|ing</t>
# d2rq                                                                        }</t>
# koku-service-api                                                            ,</t>
# naturvielfalt_android                                                      16</t>
# disruptor_1                                                                 {</t>
# AndProject                                                      0x7f|04|00|10</t>
# edsdk4j                                                   k|Ed|s|Prop|ID_|A|v</t>
# thucydides-showcase                                                        10</t>
#
#                                   Entropy
# Project
# postmark-java                    5.671923
# ibatis-handling-joins            5.762738
# logmx                            5.852840
# mod-installer                    6.134351
# servletjspdemo                   6.188181
# MCBans                           6.211582
# RPS                              6.334267
# fasthat                          6.402121
# Clara                            6.404533
# twitterdroid                     6.405383
# 1160-Scouting-App                6.548090
# osgiutils_1                      6.618498
# GrandUI                          6.625292
# gat                              6.978001
# xebia-petclinic                  6.982177
# confcaller                       7.084246
# bioclipse.opentox                7.237666
# asakusafw                        7.305793
# jbpm-plugin                      7.338547
# rdt                              7.431853
# Journal.IO                       7.509402
# hands-on-spring-batch            7.614275
# PipesJ2ME                        7.651187
# vraptor-dash                     7.673928
# SnippingTool                     7.871606
# spring-social-google             7.918419
# oddjob                           7.985153
# sveditor                         8.076013
# camel-aries-blueprint-tutorial   8.143835
# jADT                             8.227806
# android-tether                   8.261789
# d2rq                             8.322059
# koku-service-api                 8.941915
# naturvielfalt_android            8.964667
# disruptor_1                      8.982041
# AndProject                       9.169610
# edsdk4j                         11.074185
# thucydides-showcase             11.149254

# %%
per_project_entropies['Entropy'].plot.box()

# %% [markdown]
# ## Different Token Types

# %%
evaluation159.aggregate(['TokenType']).data
# Out:
#                      n_samples                      example    Entropy
# TokenType
# ClosingBracket          500373                        )</t>   0.931460
# ClosingCurlyBracket     142263                        }</t>   1.256516
# Identifier             1800496     prod|uc|er|Bar|ri|er</t>  19.047863
# KeyWord                 582531                   return</t>   2.718242
# MultilineComment         42781                <comment></t>   2.480811
# NonCodeChar             324974                        .</t>   0.544293
# Number                   14603                      4|l</t>  13.101308
# One                       9690                        1</t>   4.219729
# OneLineComment           29569                <comment></t>   3.218779
# OpeningBracket          500366                        (</t>   0.524268
# OpeningCurlyBracket     142138                        {</t>   0.525828
# Operator                820388                        .</t>   1.633154
# Semicolon               401838                        ;</t>   0.461564
# SpecialToken              8268                    <EOF></t>   3.157015
# StringLiteral            93721  "v| |l| |;| |v| |i| |a"</t>  21.327894
# Zero                     16303                        0</t>   3.143124

# %% [markdown]
# ## Identifiers of different lengths

# %%
df = evaluation159.aggregate(['SubtokenNumber', 'TokenType']).data
df.query("TokenType == 'Identifier'")
# Out:
#                            n_samples  \
# SubtokenNumber TokenType
# 1              Identifier    1012973
# 2              Identifier     345641
# 3              Identifier     213559
# 4              Identifier     119540
# 5              Identifier      62441
# 6              Identifier      21921
# 7              Identifier       9928
# 8              Identifier       5406
# 9              Identifier       2922
# 10             Identifier       1929
# 11             Identifier       1410
# 12             Identifier        914
# 13             Identifier        749
# 14             Identifier        461
# 15             Identifier        235
# 16             Identifier        133
# 17             Identifier        132
# 18             Identifier         60
# 19             Identifier         33
# 20             Identifier         17
# 21             Identifier         20
# 22             Identifier         38
# 23             Identifier          5
# 24             Identifier          4
# 25             Identifier          8
# 26             Identifier          2
# 27             Identifier         10
# 28             Identifier          1
# 29             Identifier          2
# 34             Identifier          2
#
#                                                                      example  \
# SubtokenNumber TokenType
# 1              Identifier                                            msg</t>
# 2              Identifier                                 getNext|Button</t>
# 3              Identifier                               run|With|Service</t>
# 4              Identifier                          Statement|A|ware|User</t>
# 5              Identifier                            getIn|st|all|er|Dir</t>
# 6              Identifier                   Load|able|Det|ach|able|Model</t>
# 7              Identifier                            k|Ed|s|Prop|ID_|A|v</t>
# 8              Identifier                     PUB|L|IC_|TIM|EL|IN|E_|URL</t>
# 9              Identifier     getRe|lease|An|n|oun|ce|ment|Email|Address</t>
# 10             Identifier                     FL|OR|A_|IS_|N|EO|PH|Y|T|E</t>
# 11             Identifier    should|_|se|e|_|artifact|_|detail|s_|w|here</t>
# 12             Identifier  should|Include|V|m|Statis|tic|U|sed|Memory|Per...
# 13             Identifier           H|PRO|F_|G|C_|ROOT_|J|N|I_|G|LO|B|AL</t>
# 14             Identifier  c|lick|ing_|on|_|artifact|_|should|_|display|_...
# 15             Identifier  inf|l|ate|_|single|Layout|_|layout|With|M|arg|...
# 16             Identifier  test|Create|Method|_|us|ing|All|Parameters|_in...
# 17             Identifier  if|The|Config|ured|Pattern|Do|es|Not|Match|The...
# 18             Identifier  should|_|search|_|for|_|artifact|s_|by|_|name|...
# 19             Identifier  P|_CON|T|ENT_|AS|SI|ST|_MO|DI|F|C|INST|_MAX|_P...
# 20             Identifier  k|Ed|s|Cam|er|a|Command|_|Sh|ut|ter|Button|_|C...
# 21             Identifier  test|Day|L|ight|S|av|ing|In|Aut|um|n|Over|M|id...
# 22             Identifier  add|s|And|Remo|v|es|Resource|Method|sIn|Open|R...
# 23             Identifier  test|Create|Method|_|us|ing|All|Parameter|sWit...
# 24             Identifier  test|Simple|Local|Var|As|gn|In|If|Condition|Do...
# 25             Identifier  Standard|VM|Debug|ger|_C|ould|_|not|_|find|_|a...
# 26             Identifier  Runtime|Load|path|Entry|_|Un|able|_|to_|rec|ov...
# 27             Identifier  Runtime|Load|path|Entry|_|An|_|exception|_|oc|...
# 28             Identifier  Line|Wrapp|ing|Tab|Page|_s|plit|t|ing_|wrap|_|...
# 29             Identifier  Standard|VM|Runn|er|_S|pec|ified|_|work|ing_|d...
# 34             Identifier  Java|Runtime|_|V|M_|not|_f|ull|y|_|spec|ified|...
#
#                               Entropy
# SubtokenNumber TokenType
# 1              Identifier    7.960462
# 2              Identifier   21.316411
# 3              Identifier   31.727469
# 4              Identifier   43.659296
# 5              Identifier   54.098427
# 6              Identifier   62.416725
# 7              Identifier   72.291458
# 8              Identifier   80.691314
# 9              Identifier   90.079935
# 10             Identifier   99.343847
# 11             Identifier  107.511338
# 12             Identifier  113.117447
# 13             Identifier  117.995401
# 14             Identifier  130.152735
# 15             Identifier  137.772929
# 16             Identifier  150.547646
# 17             Identifier  151.959709
# 18             Identifier  173.191095
# 19             Identifier  165.500591
# 20             Identifier  177.838134
# 21             Identifier  174.990449
# 22             Identifier  217.832242
# 23             Identifier  203.280168
# 24             Identifier  174.408783
# 25             Identifier  224.735088
# 26             Identifier  242.935416
# 27             Identifier  232.897020
# 28             Identifier  245.800417
# 29             Identifier  302.709118
# 34             Identifier  351.855709

# %% [markdown]
# # Improvement with training

# %%
evaluation0 = EvaluationResult.from_path('evaluation-test-0')
evaluation0 = to_bin_entropy(evaluation0)
evaluation19 = EvaluationResult.from_path('evaluation-test-19')
evaluation19 = to_bin_entropy(evaluation19)
evaluation79 = EvaluationResult.from_path('evaluation-test-79')
evaluation79 = to_bin_entropy(evaluation79)

# %% [markdown]
# ## Overall improvement

# %%
ents = list(map(lambda e: e.total()['Entropy'], [evaluation0, evaluation19, evaluation79, evaluation159]))
epochs = [0, 19, 79, 159]

import matplotlib.pyplot as plt
plt.plot(epochs, ents)

# %% [markdown]
# ## Improvement for different token types

# %%
import pandas as pd

df = pd.DataFrame(columns = ['Epoch0', 'Epoch19', 'Epoch79', 'Epoch159'])
df['Epoch0'] = evaluation0.aggregate(['TokenType']).data.Entropy
df['Epoch19'] = evaluation19.aggregate(['TokenType']).data.Entropy
df['Epoch79'] = evaluation79.aggregate(['TokenType']).data.Entropy
df['Epoch159'] = evaluation159.aggregate(['TokenType']).data.Entropy
df.T
# Out:
# TokenType  ClosingBracket  ClosingCurlyBracket  Identifier   KeyWord  \
# Epoch0           2.280373             2.502650   24.938707  6.184727
# Epoch19          1.461864             1.459246   21.448082  3.214220
# Epoch79          1.032758             1.231907   19.555792  2.768031
# Epoch159         0.931460             1.256516   19.047863  2.718242
#
# TokenType  MultilineComment  NonCodeChar     Number       One  OneLineComment  \
# Epoch0             3.810939     2.071541  17.599946  7.091610        3.613184
# Epoch19            2.726966     0.676256  14.858365  4.689852        3.176057
# Epoch79            2.461105     0.581638  13.481422  4.349570        3.062756
# Epoch159           2.480811     0.544293  13.101308  4.219729        3.218779
#
# TokenType  OpeningBracket  OpeningCurlyBracket  Operator  Semicolon  \
# Epoch0           2.943186             3.311761  4.433158   2.506560
# Epoch19          0.837317             0.873929  2.155033   0.908638
# Epoch79          0.573191             0.538985  1.710350   0.491704
# Epoch159         0.524268             0.525828  1.633154   0.461564
#
# TokenType  SpecialToken  StringLiteral      Zero
# Epoch0        10.655935      27.415949  4.828429
# Epoch19        4.070022      23.178581  3.655467
# Epoch79        3.315053      21.747907  3.303918
# Epoch159       3.157015      21.327894  3.143124

# %%
df.T.plot()

# %% [markdown]
# ### Only a part of token types

# %%
df.loc[['Identifier', 'ClosingBracket', 'MultilineComment', 'Semicolon', 'StringLiteral']].T.plot()

# %% [markdown]
# ## Improvement for identifiers of different lengths

# %%
import pandas as pd

df = pd.DataFrame(columns = ['Epoch0', 'Epoch19', 'Epoch79', 'Epoch159'])
df['Epoch0'] = evaluation0.aggregate(['SubtokenNumber', 'TokenType']).data.query("TokenType == 'Identifier'").Entropy
df['Epoch19'] = evaluation19.aggregate(['SubtokenNumber', 'TokenType']).data.query("TokenType == 'Identifier'").Entropy
df['Epoch79'] = evaluation79.aggregate(['SubtokenNumber', 'TokenType']).data.query("TokenType == 'Identifier'").Entropy
df['Epoch159'] = evaluation159.aggregate(['SubtokenNumber', 'TokenType']).data.query("TokenType == 'Identifier'").Entropy

df.T
# Out:
# SubtokenNumber         1          2          3          4          5   \
# TokenType      Identifier Identifier Identifier Identifier Identifier
# Epoch0          12.090073  26.411617  39.576831  53.225523  66.935981
# Epoch19          9.434444  23.617907  35.154513  47.949357  59.467702
# Epoch79          8.274626  21.845917  32.467962  44.543857  55.165303
# Epoch159         7.960462  21.316411  31.727469  43.659296  54.098427
#
# SubtokenNumber         6          7           8           9           10  ...  \
# TokenType      Identifier Identifier  Identifier  Identifier  Identifier  ...
# Epoch0          79.167289  92.542924  105.287079  117.892763  130.916377  ...
# Epoch19         69.505746  80.837610   91.666053  102.375819  113.538913  ...
# Epoch79         63.741104  73.825598   82.706575   92.292290  101.894071  ...
# Epoch159        62.416725  72.291458   80.691314   90.079935   99.343847  ...
#
# SubtokenNumber          21          22          23          24          25  \
# TokenType       Identifier  Identifier  Identifier  Identifier  Identifier
# Epoch0          259.891245  271.720076  274.225620  292.410469  307.111333
# Epoch19         212.215031  238.555570  229.751671  227.729115  257.140716
# Epoch79         182.727532  222.887129  208.499286  182.828281  230.954792
# Epoch159        174.990449  217.832242  203.280168  174.408783  224.735088
#
# SubtokenNumber          26          27          28          29          34
# TokenType       Identifier  Identifier  Identifier  Identifier  Identifier
# Epoch0          308.067481  318.942509  341.943333  360.408377  422.135943
# Epoch19         263.068199  269.740472  289.996591  321.318679  377.083282
# Epoch79         250.178164  243.333681  255.043425  307.680233  357.769967
# Epoch159        242.935416  232.897020  245.800417  302.709118  351.855709
#
# [4 rows x 30 columns]

# %%
df.T.plot(legend=False)
